# %% [markdown]
# # TASK - 01:

# %% [markdown]
# # Importing necessary libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading CSV file:

# %%
df = pd.read_csv("dataset.csv", skiprows=4)

# %% [markdown]
# # Checking Top 5 Rows Data:

# %%
df.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %% [markdown]
# # Checking Data From Bottom:

# %%
df.tail(5)
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2016        2017        2018        2019        2020        2021  \
# ...

# %% [markdown]
# # Checking The Columns of The Dataset:

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %% [markdown]
# # Some Information About The Dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154480e+08  1.170538e+08  1.192160e+08  1.218878e+08  1.245835e+08
# std    3.626523e+08  3.671660e+08  3.738303e+08  3.824608e+08  3.911397e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021529e+09  3.062769e+09  3.117373e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.273111e+08  1.301581e+08  1.330127e+08  1.359425e+08  1.389705e+08
# ...

# %% [markdown]
# # Checking For Duplicates Values:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Checking For Missing Values:

# %%
df.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2021                1
# 2022                1
# 2023                1
# 2024              266
# Unnamed: 69       266
# Length: 70, dtype: int64

# %% [markdown]
# # Checking Unique Values For Columns:

# %%
print(df['Country Name'].unique())
print("\n Total no of unique countries:",df['Country Name'].nunique())
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
print(df['Country Code'].unique())
print("\n Total no of unique country code:",df['Country Code'].nunique())
# Out:
# ['ABW' 'AFE' 'AFG' 'AFW' 'AGO' 'ALB' 'AND' 'ARB' 'ARE' 'ARG' 'ARM' 'ASM'
#  'ATG' 'AUS' 'AUT' 'AZE' 'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS'
#  'BIH' 'BLR' 'BLZ' 'BMU' 'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN'
#  'CEB' 'CHE' 'CHI' 'CHL' 'CHN' 'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV'
#  'CRI' 'CSS' 'CUB' 'CUW' 'CYM' 'CYP' 'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM'
#  'DZA' 'EAP' 'EAR' 'EAS' 'ECA' 'ECS' 'ECU' 'EGY' 'EMU' 'ERI' 'ESP' 'EST'
#  'ETH' 'EUU' 'FCS' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA'
#  'GIB' 'GIN' 'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HIC'
#  'HKG' 'HND' 'HPC' 'HRV' 'HTI' 'HUN' 'IBD' 'IBT' 'IDA' 'IDB' 'IDN' 'IDX'
#  'IMN' 'IND' 'INX' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM' 'JOR' 'JPN'
#  'KAZ' 'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAC' 'LAO' 'LBN' 'LBR'
#  'LBY' 'LCA' 'LCN' 'LDC' 'LIC' 'LIE' 'LKA' 'LMC' 'LMY' 'LSO' 'LTE' 'LTU'
#  'LUX' 'LVA' 'MAC' 'MAF' 'MAR' 'MCO' 'MDA' 'MDG' 'MDV' 'MEA' 'MEX' 'MHL'
# ...

# %% [markdown]
# # Dropping Unnecessary Columns:

# %%
df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)

# %% [markdown]
# # Extarction of Top 10 Countries With Respect To Total Population:

# %%
# Step 1: Filter for population indicator
population_df = df[df['Indicator Name'] == 'Population, total']

# Step 2: Drop missing values and convert 2022 to numeric
population_df = population_df[[ 'Country Code', '2022']].dropna()
population_df['2022'] = pd.to_numeric(population_df['2022'], errors='coerce')

# Step 3: Get top 10 by population
top_10 = population_df.sort_values(by='2022', ascending=False).head(10)

# Step 4: Remove the 2022 column if no longer needed
top_10 = top_10.drop(columns=['2022'])

# Step 5: Print the result
print("Top 10 Countries by Population:")
print(top_10)
# Out:
# Top 10 Countries by Population:
#     Country Code
# 259          WLD
# 103          IBT
# 140          LMY
# 156          MIC
# 102          IBD
# 62           EAR
# 139          LMC
# 249          UMC
# 63           EAS
# 142          LTE

# %% [markdown]
# # BAR PLOT:

# %% [markdown]
# # Top Ten Countries of Total Population in Year 2022 and 2016:

# %%
# Filter for "Population, total"
pop_df = df[df['Indicator Name'] == 'Population, total']

# Remove aggregates: keep only rows where 'Country Code' is 3 letters (most countries)
pop_countries = pop_df[pop_df['Country Code'].str.len() == 3]

# Convert population columns to numeric
pop_countries['2016'] = pd.to_numeric(pop_countries['2016'], errors='coerce')
pop_countries['2022'] = pd.to_numeric(pop_countries['2022'], errors='coerce')

# Get top 10 countries for 2016
top10_2016 = pop_countries.nlargest(10, '2016')[['Country Code', '2016']]

# Get top 10 countries for 2022
top10_2022 = pop_countries.nlargest(10, '2022')[['Country Code', '2022']]

# Plot side by side
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.barplot(x='2016', y='Country Code', data=top10_2016, palette='coolwarm')
plt.title('Top Ten Countries by Total Population (2016)', fontsize=12)
plt.xlabel('Total Population', fontsize=10)
plt.ylabel('Country', fontsize=10)

plt.subplot(1, 2, 2)
sns.barplot(x='2022', y='Country Code', data=top10_2022, palette='coolwarm')
plt.title('Top Ten Countries by Total Population (2022)', fontsize=12)
plt.xlabel('Total Population', fontsize=10)
plt.ylabel('Country', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_14084\1676151282.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='2016', y='Country Code', data=top10_2016, palette='coolwarm')
# C:\Users\srini\AppData\Local\Temp\ipykernel_14084\1676151282.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='2022', y='Country Code', data=top10_2022, palette='coolwarm')

# %% [markdown]
# # Extraction of bottom 10 countries with respect to total popultaion:

# %%
# Filter for "Population, total"
pop_df = df[df['Indicator Name'] == 'Population, total']

# Remove aggregates: keep only rows where 'Country Code' is 3 letters (most countries)
pop_countries = pop_df[pop_df['Country Code'].str.len() == 3]

# Convert the 2022 column to numeric
pop_countries['2022'] = pd.to_numeric(pop_countries['2022'], errors='coerce')

# Sort data based on the total population for 2022 (ascending order)
total_population_sorted1 = pop_countries.sort_values(by="2022", ascending=True)

# Get the bottom ten countries with the lowest total population for 2022
total_bottom_ten_countries = total_population_sorted1.head(10)

# Check columns
print("Columns in DataFrame:", total_bottom_ten_countries.columns.tolist())

# Print the desired columns (make sure they exist)
print("Bottom ten countries of total population (2022)\n")
print(total_bottom_ten_countries[['Country Name', 'Country Code', '2022']])
# Out:
# Columns in DataFrame: ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', 'Unnamed: 69']
# Bottom ten countries of total population (2022)
#
#                  Country Name Country Code     2022
# 245                    Tuvalu          TUV   9992.0
# 179                     Nauru          NRU  11801.0
# 188                     Palau          PLW  17759.0
# 147  St. Martin (French part)          MAF  28870.0
# ...

# %% [markdown]
# # Bottom ten countries of total population in year 2022 and 2016:

# %%
# Filter for "Population, total"
pop_df = df[df['Indicator Name'] == 'Population, total']

# Keep only actual countries (country codes are 3 letters)
pop_countries = pop_df[pop_df['Country Code'].str.len() == 3]

# Convert population columns to numeric
pop_countries['2016'] = pd.to_numeric(pop_countries['2016'], errors='coerce')
pop_countries['2022'] = pd.to_numeric(pop_countries['2022'], errors='coerce')

# Get the bottom ten countries by population for 2016 and 2022
bottom10_2016 = pop_countries.nsmallest(10, '2016')[['Country Code', '2016']]
bottom10_2022 = pop_countries.nsmallest(10, '2022')[['Country Code', '2022']]

# Plot both in the same figure
plt.figure(figsize=(15, 6))

# 2016 subplot
plt.subplot(1, 2, 1)
sns.barplot(x='2016', y='Country Code', data=bottom10_2016, palette='coolwarm')
plt.title('Bottom Ten Countries by Total Population (2016)', fontsize=12)
plt.xlabel('Total Population', fontsize=10)
plt.ylabel('Country', fontsize=10)

# 2022 subplot
plt.subplot(1, 2, 2)
sns.barplot(x='2022', y='Country Code', data=bottom10_2022, palette='coolwarm')
plt.title('Bottom Ten Countries by Total Population (2022)', fontsize=12)
plt.xlabel('Total Population', fontsize=10)
plt.ylabel('Country', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_14084\599930598.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='2016', y='Country Code', data=bottom10_2016, palette='coolwarm')
# C:\Users\srini\AppData\Local\Temp\ipykernel_14084\599930598.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='2022', y='Country Code', data=bottom10_2022, palette='coolwarm')

# %% [markdown]
# # Extarction of top 10 countries with highest male population:

# %%
# Remove aggregates: keep only rows where 'Country Code' is 3 letters (most countries)
pop_countries = df[(df['Indicator Code'] == 'SP.POP.TOTL') & (df['Country Code'].str.len() == 3)]

# Convert the 2022 column to numeric
pop_countries['2022'] = pd.to_numeric(pop_countries['2022'], errors='coerce')

# Sort data based on the total population for 2022 (descending order)
pop_sorted = pop_countries.sort_values(by="2022", ascending=False)

# Get the top 10 countries with the highest total population for 2022
top_ten_countries = pop_sorted.head(10)

print("Top ten countries of total population (2022):")
print(top_ten_countries[['Country Name', 'Country Code', '2022']])
# Out:
# Top ten countries of total population (2022):
#                    Country Name Country Code          2022
# 259                       World          WLD  7.989982e+09
# 103            IDA & IBRD total          IBT  6.795222e+09
# 140         Low & middle income          LMY  6.568732e+09
# 156               Middle income          MIC  5.851866e+09
# 102                   IBRD only          IBD  4.928694e+09
# 62   Early-demographic dividend          EAR  3.470645e+09
# 139         Lower middle income          LMC  3.041204e+09
# 249         Upper middle income          UMC  2.810662e+09
# 63          East Asia & Pacific          EAS  2.379648e+09
# 142   Late-demographic dividend          LTE  2.324072e+09

# %%
# Choose the country
chosen_country = 'United States'

# Filter for total population indicator and the chosen country
country_data = df[
    (df['Country Name'] == chosen_country) &
    (df['Indicator Code'] == 'SP.POP.TOTL')
]

# Select only the year columns (from 1960 to 2024)
year_cols = [col for col in country_data.columns if col.isdigit()]
years = list(map(int, year_cols))
population = country_data[year_cols].values.flatten()

# Convert population to numeric (in case of missing/empty values)
population = pd.to_numeric(population, errors='coerce')

# Plot
plt.figure(figsize=(12, 5))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {chosen_country} Over the Years')
plt.tight_layout()
plt.show()

# %%
plt.hist(population, bins=30, color='brown', edgecolor='black')
plt.show()

# %%
# Filter for total population indicator and actual countries (3-letter codes)
pop_countries = df[(df['Indicator Code'] == 'SP.POP.TOTL') & (df['Country Code'].str.len() == 3)]

# Convert 2022 column to numeric
pop_countries['2022'] = pd.to_numeric(pop_countries['2022'], errors='coerce')

# Get top 10 countries by total population in 2022
top10_2022 = pop_countries.sort_values(by='2022', ascending=False).head(10)

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x='2022', y='Country Code', data=top10_2022, palette='viridis')
plt.title("Top Ten Countries by Total Population (2022)", fontsize=12)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_14084\3939602993.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='2022', y='Country Code', data=top10_2022, palette='viridis')
